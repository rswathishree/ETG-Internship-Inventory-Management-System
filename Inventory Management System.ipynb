# %%
#importing necessary packages
import json
import datetime

#Selecting between Customer and Salesteam
print("-----------------------------------------------------------------------------------------------------------------------")
print("             ","\U0001F600","Welcome to Swathi's Inventory Management System","\U0001F600")
print("-----------------------------------------------------------------------------------------------------------------------")
print("\U0001F914","Are you a ***Customer*** or ***Sales Team*** ?","\U0001F914")
Actor=input("Enter 'C' for customer or 'S' for Sales Team: ")
print("You have Entered ",Actor,"\U0001F603")
print("***********************************************************************************************************************")

#loading record.json and sales.json files
fd = open("record.json",'r')
txt = fd.read()
fd.close()
record = json.loads(txt)
fd1 = open("sale.json",'r')
txt1 = fd1.read()
fd1.close()
sale = json.loads(txt1)

#Code for Customer
if (Actor=='C' or Actor=='c'):
    print("------------------------------------","\U0001F60E","Welcome Dear Customers!!!","\U0001F60E","-------------------------------------------------")
    key=record.keys()
    count=0
    ch='y'
    id_list=[]
    pro_list=[]
    price_list=[]
    quant_list=[]
    a_list=[]
    amount=0
    
    #customer Ordering products section
    name=input("Enter your name:  ")
    number=input("Enter your phone number:  ")
    
    #Displaying List Of Products
    print("********************************************************************************************************************")
    print("\U0001F60E","-------The following are the products we have-----------","\U0001F60E")
    print("ID\t\tName\t\t Price\t\tAvailable Stock\t  Company Name\t\t Expiry Date\t\t  Type")
    for i in key:
        name1=format(record[i]['name'],'.^20')
        price=record[i]['Price']
        print(i,"\t",name1,"\tRs",format(str(price)+" /-",'^8'),"\t",format(record[i]['quantity'],'^5'),"\t\t  ",format(record[i]['company'],'^15'),"\t",format(record[i]['expiry'],'^10'),"\t\t",record[i]['type'])
    print("\U0001F446","-----------Select from the above list----------","\U0001F446")
    while(True):
        
        #Getting Product ID
        print("Enter the id of the product which you want to order (refer above)","\U0001F446" )
        ui_prod  = input("Enter the product_Id: ")
        
        
        if ui_prod in key:
            print("Selected Product: ",record[ui_prod]['name'])
            ui_quant = int(input("Enter the quantity: "))
            
            #If the quantity entered is less than stock
            if ui_quant<=int(record[ui_prod]['quantity']):
                print(record[ui_prod]['name'],end="  ")
                print("Rs",record[ui_prod]['Price'],"/- per unit")
                am=int(ui_quant * int(record[ui_prod]['Price']))
                print("Price = ",am)
                a_list.append(am)
                id_list.append(ui_prod)
                pro_list.append(record[ui_prod]['name'])
                price_list.append(record[ui_prod]['Price'])
                quant_list.append(ui_quant)
                count+=1
                amount+=am
                record[ui_prod]['quantity']-=ui_quant
                print("---------------------------------------------------------------------------------------------------------")
                print("Total  Bill : ", amount)
                print("***********************")
                ch=input("do you want to continue shopping?(y/n) ")
                print("**********************************************************************************************************")
                if(ch!='y' and ch!='Y'):
                    break
                    
            #If the quantity entered is greater than stock
            else:
                print("***********************************************************************************************************")
                print("Available quantity is ",record[ui_prod]['quantity'], "\n Do you want to order it?")
                ord=input("enter y or n :")
                
                #if the customer accepts ordering available Stock
                if ord=='y':
                    print(record[ui_prod]['name'],end="  ")
                    print("Rs",record[ui_prod]['Price'],"/- per unit")
                    am=int(int(record[ui_prod]['quantity'])* int(record[ui_prod]['Price']))
                    print("Price = ",am)
                    a_list.append(am)
                    id_list.append(ui_prod)
                    pro_list.append(record[ui_prod]['name'])
                    price_list.append(record[ui_prod]['Price'])
                    quant_list.append(record[ui_prod]['quantity'])
                    count+=1
                    amount+=am
                    record[ui_prod]['quantity']= 0
                    print("-----------------------------------------------------------------------------------------------------")
                    print("Total  Bill : ", amount)
                    print("******************************************************************************************************")
                    
                    ch=input("Do you want to continue shopping?(y/n) ")
                    
                    if(ch!='y' and ch!='Y'):
                        break
                        
                # if the customer rejects ordering available Stock
                else:
                    ch=input("do you want to continue shopping?(y/n) ")
                    if(ch!='y' and ch!='Y'):
                        break
                    continue
        
        # if the enters the wrong Project ID
        else:
            print("*****************************************************************************************************************")
            print("#######----------->>>","\U0001F613","Recheck the Product ID you entered, You have entered a wrong one!!","\U0001F613","!<<<--------------###########")
            continue
            
    # Generating the Bill
    print("**********************************************************************************************************************")
    print("<<<<<---------------------------------------Generating Bills----------------------------------------------------->>>>>")
    now = datetime.datetime.now()
    time1=now.strftime("%Y-%m-%d %H-%M-%S")
    print("Customer Name: ", name,end= "    ")
    print("Mobile Number:",number)
    print("Transaction Date and Time: ",time1)
    print("------------------------------------------------------------------------------------------------------------------------")
    print("ID\t\t  Name\t\t   Price  *  Quantity\t\t Cost")
    
    for i in range(0,count):
        
        print(i+1,"\t   ",format(pro_list[i],'.^20'),"\t ",price_list[i],"*",quant_list[i],"\t\tRs",a_list[i],"/-")
    print("------------------------------------","Total Bill: Rs",amount,"/- ------------------------------------------------------")
    
    # Applying the Discounts
    if(amount<500):
        discount=0
        amount1=amount
        print("                             you have to pay Rupees ", amount1,"only                                                   ")
        print(".............","\U0001F607","Final Bill Amount :Rs "+str(amount1)+" /-","\U0001F607",".....................")
        print("***********************************************************************************************************************")
    elif(amount>=500 and amount<1000):
        discount=amount*0.15
        amount1=amount-discount
        print("------------------------------------------------------------------------------------------------------------------------")
        print("       ","\U0001F917"," Hurray! you have purchased more than 500 Rupees. So you avail a discount of 15% ","\U0001F917","    ")
        print("                             you have saved Rs ",discount,"/- in this visit                                            " )
        print("-------------------------------------------------------------------------------------------------------------------------")
        print("                               you have to pay Rupees ", amount1,"only    ")
        print(".............","\U0001F607","Final Bill Amount :Rs "+str(amount1)+" /-","\U0001F607",".......................")
        print("**************************************************************************************************************************")
    else:
        discount=amount*0.25
        amount1=amount-discount
        print("--------------------------------------------------------------------------------------------------------------------------")
        print("  ","\U0001F917"," Hurray! you have purchased more than 1000 Rupees. So you avail a discount of 25% ","\U0001F917","      ")
        print("                           you have saved Rs ",discount,"/- in this visit                                          " )
        print("--------------------------------------------------------------------------------------------------------------------------")
        print("                            you have to pay Rupees ", amount1,"only                                                 ")
        print("............","\U0001F607","Final Bill Amount :Rs "+str(amount1)+" /-","\U0001F607","....................")
        print("***************************************************************************************************************************")
    
    # Printing invoice
    print("Do,You want your bill-invoice?")
    invoice=input("Enter yes or no (y/n): ")
    if(invoice=='Y' or invoice=='y'):
        print("Your Invoice is generated successfully","\U0001F91D")
        a=name+"-"+time1+"-invoice.text"
        fd = open(a,'w')
        fd.write("**********************************************************************************************************************\n")
        fd.write("<<<<<---------------------------------------Generating Invoice----------------------------------------------------->>>>>\n")
        fd.write("Customer Name: "+name+"       Mobile Number: "+number+"      Transaction Date and Time: "+time1+"\n")
        fd.write("------------------------------------------------------------------------------------------------------------------------\n")
        fd.write("Slno\t\t  Name\t\t   Price  *  Quantity\t\t Cost\n")
        for i in range(0,count):
            a=str(i+1)
            fd.write(a+" \t    "+str(format(pro_list[i],'.^20'))+" \t  "+str(price_list[i])+" * "+str(quant_list[i])+" \t\tRs "+str(a_list[i])+" /-\n")
        fd.write("------------------------------------"+"Total Bill: Rs "+str(amount)+" /- ------------------------------------------------------\n")
        if(amount<500):
            fd.write("------------------------------------------------------------------------------------------------------------------------\n")
            fd.write("                            you have to pay Rupees "+str(amount1)+" only\n")
        elif(amount>=500 and amount<1000):
            fd.write("------------------------------------------------------------------------------------------------------------------------\n")
            fd.write("                Hurray! you have purchased more than 500 Rupees. So you avail a discount of 15%                    \n ")
            fd.write("                   you have saved Rs "+str(discount)+" /- in this visit                                      \n " )
            fd.write("-------------------------------------------------------------------------------------------------------------------------\n")
            fd.write("                        you have to pay Rupees "+str(amount1)+" only                                      \n ")
            fd.write("**************************************************************************************************************************\n")
        else: 
            fd.write("------------------------------------------------------------------------------------------------------------------------\n")
            fd.write("               Hurray! you have purchased more than 1000 Rupees. So you avail a discount of 25%           \n")
            fd.write("                  you have saved Rs "+str(discount)+" /- in this visit                                    \n" )
            fd.write("--------------------------------------------------------------------------------------------------------------------------\n")
            fd.write("                 Final Bill Amount :Rs "+str(amount1)+" /-                     \n")
            fd.write("                     you have to pay Rupees "+ str(amount1)+" only                                          \n")
            fd.write("***************************************************************************************************************************\n")
        fd.write("************************************----Thank You, Visit Again!!!----**********************************************************\n")
        fd.write("************************************************************************************************************************************\n")
        fd.close()
    print("*******************","\U0001F64F","\U0001F64F","----Thank You, Visit Again!!!----","\U0001F64F","\U0001F64F","******************\n")
    print("***************************************************************************************************************************\n")
    # inserting the Customer-Purchase details into Sales.json
    sale_list=list(sale.keys())
    items={} 
    for i in range(0,count):
        items[len(items)+1]={"Product_ID":id_list[i],"product_name":pro_list[i],"product_price":price_list[i],"quantity":quant_list[i]}
        
    if len(sale_list)==0:
        tran_id='1'
        sale.update({tran_id: {"Customer-name":name , " Ph-Number": number, "Products":items,"Total":amount,"Discount":discount, "Bill Amount":amount1,"Time":time1 }})
    else:
        tran_id=str(int(sale_list[-1])+1)
        sale.update({tran_id: {"Customer-name":name , "Ph-Number": number,"Products":items,"Total":amount,"Discount":discount, "Bill Amount":amount1,"Time":time1 }})

# Code for Sales-Person
elif(Actor=='S' or Actor=='s'):
    admin='abcde'
    che='y'
    con='y'
    dis=0
    while(True):
        
        # Authentication using Password, Here Passward = "abcde"
        print("--------------------------------","\U0001F60E","Welcome Sales Team!!!","\U0001F60E","--------------------------------------")
        print("The password is",admin,"(given for reference)")
        password=input("Enter the Sales Team password: ")
        
        # If Password is correct
        if(admin==password):
            print("#######################-----------------","\U0001F60E","Welcome Team","\U0001F60E","------------######################")
            fd = open("record.json",'r')
            txt = fd.read()
            fd.close()
            record = json.loads(txt)
            saleconst=input("Enter the appropriate number \n 1: Adding products \n 2: Viewing sales \n 1 or 2: ")
            print("You have entered ",saleconst)
            #For Adding Products
            if(saleconst=='1'):
                while(True):
                    
                    # Getting Product-ID
                    print("Enter the Product Id which you are going to add")
                    prodid  = input("Enter the product_Id: ")
                    
                    # IF Product-ID already existing
                    if prodid in record.keys():
                        print("Cool, that is an Existing product!!!!")
                        print("Product Name: ",record[prodid]['name'])
                        print("..........................................................")
                        prodquant = int(input("Enter the Quantity of products, you are adding: "))
                        
                        #Updating the stock
                        record[prodid]['quantity']+=prodquant
                        
                    # IF Product-ID is new (i.e) adding new Products
                    else:
                        print("Enter the details of the new product")
                        print("............................................................")
                        prodname  = input("Enter the product Name: ")
                        prodprice = int(input("Enter the product Price: "))
                        prodquant = int(input("Enter the Product Quantity: "))
                        prodcompany  = input("Enter the product Company Name: ")
                        prodexpire = input("Enter the product's Expiry date: ")
                        prodtype = input("Enter the category of the product: ")
                        
                        # Adding the new product to record.json
                        record.update({prodid: {"name":prodname , "Price": prodprice, "quantity": prodquant,"company":prodcompany,"expiry":prodexpire,"type":prodtype}})

                    print("------------------------------------------------------------------------------------------------------------------------------")
                    che=input("Do you want to continue loading Stock? (y/n) ")
                    if(che!='y'):
                        print("        ","\U0001F44D","You have successfuly added the stock!!!","\U0001F44D","")
                        print("----------------------------------------------------------------------------------------------------------")
                        print("*******************************","\U0001F607","-Thank You!!!---","\U0001F607","***********************************")
                        dis=1
                        break
                    else:
                        continue
            elif(saleconst=='2'):
                #Viewing the Contents of Sale.json file
                print("************************************************************************************************************************")
                print("------------","\U0001F44D","You Are Viewing the contents of the Sales.json file","\U0001F44D","-----------------------------")
                keys=sale.keys()
                print("------------------------------------------------------------------------------------------------------------------------") 
                
                # Displaying the details of the sales
                for i in keys:
                    print("                                   Transaction:",i)
                    print("***********************************************************************************************************")
                    print("Customer-name: ",sale[i]['Customer-name'],end="\t\t")
                    print("Ph-Number: ",sale[i]['Ph-Number'],end="\t\t")
                    print("Time: ",sale[i]['Time'])
                    print("------------------------------------------------------------------------------------------------------------------")
                    keys1=sale[i]['Products'].keys()
                    print("SL_No\t  Product ID\t\t Product Name\t\tProduct Price\t\t\tQuantity")
                    print("------------------------------------------------------------------------------------------------------------------")
                    
                    # Displaying the products purchased in each transanction
                    for j in keys1:
                        print(j,"\t",format(sale[i]['Products'][j]['Product_ID'],'^15'),"\t",format(sale[i]['Products'][j]['product_name'],'^15'),"\t",format(sale[i]['Products'][j]['product_price'],'^15'),"\t",format(sale[i]['Products'][j]['quantity'],'^15'))
                    print("-----------------------------------------------------------------------------------------------------------")
                    print("Total: ",sale[i]['Total'],end="\t\t\t")
                    print("Discount: ",sale[i]['Discount'],end="\t\t\t")
                    print("Bill Amount: ",sale[i]['Bill Amount'])
                    print("***********************************************************************************************************")
                    print("\n")
                print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
                print("********************************","\U0001F973","----Thanks for visiting our website------","\U0001F973","**************************************")
                print("*******************************************************************************************************************") 
                dis=1
            else:
                print("________________","\U0001F613","You have entered a wrong option, Try re-executing the program","\U0001F613","____________________________")
                dis=1
                
            if dis!=0:
                break
        else:
            
            # If the Password entered is wrong 
            print("**************************************************************************************************************************")
            print("################..................","\U0001F613","OOPS!!! Password is wrong,","\U0001F613","..............................####################")
            print("--------------------------------------------------------------------------------------------------------------------------")
            con=input("do you want to retry ? ")
            if(con!='y' and con!='Y'):
                print("**********************************************************************************************************************")
                print("**************************","\U0001F973","*-Thanks for visiting our website---","\U0001F973","*******************************************")
                print("**********************************************************************************************************************") 
                break
            else:
                continue
                
# if the user has pressed anyother option other than C or S
else:
    print("_____________________","\U0001F613","You have entered a wrong option Try re-executing the program","\U0001F613","__________________________________")
    

# Writing the record.json and Sale.json files after manipulating    
js = json.dumps(record)
fd = open("record.json",'w')
fd.write(js)
fd.close()
js1 = json.dumps(sale)
fd1 = open("sale.json",'w')
fd1.write(js1)
fd1.close()
# Out:
# -----------------------------------------------------------------------------------------------------------------------
#               😀 Welcome to Swathi's Inventory Management System 😀
# -----------------------------------------------------------------------------------------------------------------------
# 🤔 Are you a ***Customer*** or ***Sales Team*** ? 🤔
# Enter 'C' for customer or 'S' for Sales Team: c
# You have Entered  c 😃
# ***********************************************************************************************************************
# ------------------------------------ 😎 Welcome Dear Customers!!! 😎 -------------------------------------------------
# Enter your name:  Mahalingam
# Enter your phone number:  98979899
# ********************************************************************************************************************
# 😎 -------The following are the products we have----------- 😎
# ...
